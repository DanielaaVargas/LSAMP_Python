# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielaaVargas/LSAMP_Python/blob/main/Copy_of_Jupyter_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install astropy==3.5;
# !pip install pyregion;
# !pip install photutils;
# !pip install regions;
# !pip install scipy;
# !pip install aplpy

# %%
import numpy as np
from astropy.io import fits
from astropy.wcs import WCS
import matplotlib.pyplot as plt
import pyregion
from astropy.coordinates import Angle
from astropy import units as u
from astropy.stats import SigmaClip
from photutils.background import StdBackgroundRMS
from regions import Regions
from pyregion import get_mask
import aplpy
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Drive_path = '/content/drive/MyDrive/NINE/'
Image = Drive_path + 'Imaging/NGC5258.fits'

# %%
iMg = aplpy.FITSFigure(Image)
iMg.set_title("NGC5258")
iMg.show_colorscale(cmap='jet')
iMg.add_colorbar()
iMg.add_grid()
iMg.add_beam()
iMg.beam.set_color('red')
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56756.360104 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56756.360104 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -107.618000 from OBSGEO-[XYZ].
# Set OBSGEO-B to    34.078827 from OBSGEO-[XYZ].
# Set OBSGEO-H to     2115.607 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -107.618000 from OBSGEO-[XYZ].
# Set OBSGEO-B to    34.078827 from OBSGEO-[XYZ].
# Set OBSGEO-H to     2115.607 from OBSGEO-[XYZ]'.
# INFO:astropy:Auto-setting vmin to -1.012e-04
# INFO:astropy:Auto-setting vmax to  5.048e-04
# INFO: Auto-setting vmin to -1.012e-04 [aplpy.core]
# INFO: Auto-setting vmax to  5.048e-04 [aplpy.core]

# %%
IMG =fits.open('/content/drive/MyDrive/NINE/Imaging/NGC5258.fits')
image = IMG[0].data.sum()
image
# Out:
# 3.587452

# %%
vla_image, header = fits.getdata(Image, header = True)
region_file = Drive_path + 'Imaging/DS9.reg'
region = pyregion.open(region_file)
region
# Out:
# [Shape : circle ( Number(53),Number(419),Number(20) ),
#  Shape : circle ( Number(393),Number(449),Number(19.932905) ),
#  Shape : circle ( Number(441),Number(320),Number(27.573967) ),
#  Shape : circle ( Number(38.456),Number(60.92),Number(24.447757) ),
#  Shape : circle ( Number(145.592),Number(54.008),Number(23.584063) ),
#  Shape : circle ( Number(453.176),Number(107.576),Number(14.395013) ),
#  Shape : circle ( Number(73.016),Number(192.248),Number(53.362276) ),
#  Shape : circle ( Number(373.688),Number(352.952),Number(39.456229) )]

# %%
rms_values = []
for K in range(len(region)):
  region = pyregion.open(region_file)
  m=len(region)
  del region[0:K]
  del region[1:m]

  mask = region.get_mask(shape=(vla_image.shape[0],vla_image.shape[1]), header=header)
  #mask = get_mask(region,data)
  maskdata= np.multiply(vla_image,mask)
  N=len(maskdata[maskdata!=0])
  rms_values.append(np.sqrt(np.sum(maskdata**2)/N))
avg_rms = np.mean(rms_values)
avg_rms
# Out:
# 1.8055913129607442e-05

# %%
#regions = Regions.read('my_regions.reg', format='ds9')  (try this!)

#So, if I select the region of clearly real emission, the avg "noise" is 5 orders higher than the actual avg noise.
#Conclusion: I need to select the regions carefully so that I don't take into account real emission by accident.
vla_image = fits.getdata(Image)
noise = Drive_path + 'Imaging/ds9noise'
region = pyregion.open(noise)
region

rms_values = []
for K in range(len(region)):
  region = pyregion.open(noise)
  m=len(region)
  del region[0:K]
  del region[1:m]

  mask = region.get_mask(shape=(vla_image.shape[0],vla_image.shape[1]), header=header)
  #mask = get_mask(region,data)
  maskdata= np.multiply(vla_image,mask)
  N=len(maskdata[maskdata!=0])
  rms_values.append(np.sqrt(np.sum(maskdata**2)/N))
avg_rms = np.mean(rms_values)
avg_rms
# Out:
# 0.00018139071935743522
